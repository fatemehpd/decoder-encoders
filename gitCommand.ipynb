# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# %cd /content/drive/MyDrive/brain-CT
# !git fetch
# Out:
# /content/drive/MyDrive/brain-CT

# %%
# !git pull
# Out:
# Already up to date.

# %%
# !git status
# Out:
# Refresh index: 100% (11/11), done.
# On branch classifier
# Your branch is up to date with 'origin/classifier'.
#
# nothing to commit, working tree clean

# %%
# !git add -A

# %%
# !git commit -m"fix"
# Out:
# [classifier 1126531] fix
#  1 file changed, 1 insertion(+), 1 deletion(-)
#  rewrite gitCommand.ipynb (68%)

# %%
# !git branch
# Out:
# * classifier
#   master
#   remotes/origin/HEAD -> origin/master
#   remotes/origin/Unet
#   remotes/origin/classifier
#   remotes/origin/master

# %%
# !git push
# Out:
# To https://github.com/mamdaliof/brain-CT.git
#  ! [rejected]        classifier -> classifier (non-fast-forward)
# error: failed to push some refs to 'https://github.com/mamdaliof/brain-CT.git'
# hint: Updates were rejected because the tip of your current branch is behind
# hint: its remote counterpart. Integrate the remote changes (e.g.
# hint: 'git pull ...') before pushing again.
# hint: See the 'Note about fast-forwards' in 'git push --help' for details.
